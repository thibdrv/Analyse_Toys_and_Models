# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/thibdrv/Toys_and_Models/refs/heads/main/EDA_Exploratory_Data_Analysis/Toys_and_Models_Cleaned.csv")
df
# Out:
#       quantityOrdered  priceEach   orderDate requiredDate shippedDate  \
# 0                  30     136.00  2018-01-06   2018-01-13  2018-01-10
# 1                  50      55.09  2018-01-06   2018-01-13  2018-01-10
# 2                  22      75.46  2018-01-06   2018-01-13  2018-01-10
# 3                  49      35.29  2018-01-06   2018-01-13  2018-01-10
# 4                  25     108.06  2018-01-09   2018-01-18  2018-01-11
# ...               ...        ...         ...          ...         ...
# 2644               39      46.29  2020-02-17   2020-02-23  2020-02-18
# 2645               20     120.12  2020-02-17   2020-02-23  2020-02-18
# 2646               33      97.39  2020-02-17   2020-02-23  2020-02-18
# 2647               26      85.72  2020-02-17   2020-02-23  2020-02-18
# 2648               48      57.53  2020-02-17   2020-02-23  2020-02-18
#
#      orderStatus                                   orderComments  \
# 0        Shipped                                             NaN
# 1        Shipped                                             NaN
# 2        Shipped                                             NaN
# 3        Shipped                                             NaN
# 4        Shipped                          Check on availability.
# ...          ...                                             ...
# 2644     Shipped  Custom shipping instructions sent to warehouse
# 2645     Shipped  Custom shipping instructions sent to warehouse
# 2646     Shipped  Custom shipping instructions sent to warehouse
# 2647     Shipped  Custom shipping instructions sent to warehouse
# 2648     Shipped  Custom shipping instructions sent to warehouse
#
#                                       productName          category  \
# 0                        1917 Grand Touring Sedan      Vintage Cars
# 1                              1911 Ford Town Car      Vintage Cars
# 2             1932 Alfa Romeo 8C2300 Spider Sport      Vintage Cars
# 3                1936 Mercedes Benz 500k Roadster      Vintage Cars
# 4                       1932 Model A Ford J-Coupe      Vintage Cars
# ...                                           ...               ...
# 2644                      1939 Cadillac Limousine      Vintage Cars
# 2645                     1962 Volkswagen Microbus  Trucks and Buses
# 2646                        1936 Chrysler Airflow      Vintage Cars
# 2647                  1980’s GM Manhattan Express  Trucks and Buses
# 2648  1996 Peterbilt 379 Stake Bed with Outrigger  Trucks and Buses
#
#      productScale  ...                    employeeEmail   jobTitle  \
# 0            1:18  ...  spatterson@classicmodelcars.com  Sales Rep
# 1            1:18  ...  spatterson@classicmodelcars.com  Sales Rep
# 2            1:18  ...  spatterson@classicmodelcars.com  Sales Rep
# 3            1:24  ...  spatterson@classicmodelcars.com  Sales Rep
# 4            1:18  ...      bjones@classicmodelcars.com  Sales Rep
# ...           ...  ...                              ...        ...
# 2644         1:18  ...   ljennings@classicmodelcars.com  Sales Rep
# 2645         1:24  ...   ljennings@classicmodelcars.com  Sales Rep
# 2646         1:24  ...   ljennings@classicmodelcars.com  Sales Rep
# 2647         1:32  ...   ljennings@classicmodelcars.com  Sales Rep
# 2648         1:32  ...   ljennings@classicmodelcars.com  Sales Rep
#
#         city_office      phone_office country_office territory  \
# 0            Boston   +1 215-837-0825            USA       NaN
# 1            Boston   +1 215-837-0825            USA       NaN
# 2            Boston   +1 215-837-0825            USA       NaN
# 3            Boston   +1 215-837-0825            USA       NaN
# 4            London  +44 20 7877 2041             UK      EMEA
# ...             ...               ...            ...       ...
# 2644  San Francisco   +1 650-219-4782            USA       NaN
# 2645  San Francisco   +1 650-219-4782            USA       NaN
# 2646  San Francisco   +1 650-219-4782            USA       NaN
# 2647  San Francisco   +1 650-219-4782            USA       NaN
# 2648  San Francisco   +1 650-219-4782            USA       NaN
#
#          employeeName    contactName                        address_office  \
# 0     Steve Patterson  Dorothy Young      1550 Court Place Suite 102 02107
# 1     Steve Patterson  Dorothy Young      1550 Court Place Suite 102 02107
# 2     Steve Patterson  Dorothy Young      1550 Court Place Suite 102 02107
# 3     Steve Patterson  Dorothy Young      1550 Court Place Suite 102 02107
# 4         Barry Jones  Roland Keitel  25 Old Broad Street Level 7 EC2N 1HN
# ...               ...            ...                                   ...
# 2644  Leslie Jennings   Susan Nelson     100 Market Street Suite 300 94080
# 2645  Leslie Jennings   Susan Nelson     100 Market Street Suite 300 94080
# 2646  Leslie Jennings   Susan Nelson     100 Market Street Suite 300 94080
# 2647  Leslie Jennings   Susan Nelson     100 Market Street Suite 300 94080
# 2648  Leslie Jennings   Susan Nelson     100 Market Street Suite 300 94080
#
#                      address_customer
# 0     2304 Long Airport Avenue  62005
# 1     2304 Long Airport Avenue  62005
# 2     2304 Long Airport Avenue  62005
# 3     2304 Long Airport Avenue  62005
# 4                Lyonerstr. 34  60528
# ...                               ...
# 2644           5677 Strong St.  97562
# 2645           5677 Strong St.  97562
# 2646           5677 Strong St.  97562
# 2647           5677 Strong St.  97562
# 2648           5677 Strong St.  97562
#
# [2649 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2649 entries, 0 to 2648
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   quantityOrdered   2649 non-null   int64
#  1   priceEach         2649 non-null   float64
#  2   orderDate         2649 non-null   object
#  3   requiredDate      2634 non-null   object
#  4   shippedDate       2587 non-null   object
#  5   orderStatus       2649 non-null   object
#  6   orderComments     638 non-null    object
#  7   productName       2649 non-null   object
#  8   category          2649 non-null   object
#  9   productScale      2649 non-null   object
#  10  productVendor     2649 non-null   object
#  11  quantityInStock   2649 non-null   int64
#  12  buyPrice          2649 non-null   float64
#  13  MSRP              2649 non-null   float64
#  14  customerName      2649 non-null   object
#  15  phone_customer    2096 non-null   object
#  16  city_customer     2649 non-null   object
#  17  country_customer  2649 non-null   object
#  18  creditLimit       2649 non-null   int64
#  19  employeeEmail     2649 non-null   object
#  20  jobTitle          2649 non-null   object
#  21  city_office       2649 non-null   object
#  22  phone_office      2649 non-null   object
#  23  country_office    2649 non-null   object
#  24  territory         1680 non-null   object
#  25  employeeName      2649 non-null   object
#  26  contactName       2649 non-null   object
#  27  address_office    2649 non-null   object
#  28  address_customer  2649 non-null   object
# dtypes: float64(3), int64(3), object(23)
# memory usage: 600.3+ KB

# %%
df.isnull().sum()
# Out:
# quantityOrdered        0
# priceEach              0
# orderDate              0
# requiredDate          15
# shippedDate           62
# orderStatus            0
# orderComments       2011
# productName            0
# category               0
# productScale           0
# productVendor          0
# quantityInStock        0
# buyPrice               0
# MSRP                   0
# customerName           0
# phone_customer       553
# city_customer          0
# country_customer       0
# creditLimit            0
# employeeEmail          0
# jobTitle               0
# city_office            0
# phone_office           0
# country_office         0
# territory            969
# employeeName           0
# contactName            0
# address_office         0
# address_customer       0
# dtype: int64

# %%
df.nunique()
# Out:
# quantityOrdered       33
# priceEach           1482
# orderDate            229
# requiredDate         229
# shippedDate          216
# orderStatus            4
# orderComments         31
# productName          109
# category               7
# productScale           8
# productVendor         13
# quantityInStock      109
# buyPrice             107
# MSRP                 107
# customerName          98
# phone_customer        75
# city_customer         77
# country_customer      21
# creditLimit           92
# employeeEmail         15
# jobTitle               1
# city_office            7
# phone_office           7
# country_office         5
# territory              3
# employeeName          15
# contactName           98
# address_office         7
# address_customer      98
# dtype: int64

# %%
df.describe()
# Out:
#        quantityOrdered    priceEach  quantityInStock     buyPrice  \
# count      2649.000000  2649.000000      2649.000000  2649.000000
# mean         34.748207    91.008335      5052.115138    54.654356
# std           9.014277    36.682176      2927.157373    22.134151
# min          20.000000    26.550000        15.000000    15.910000
# 25%          27.000000    62.050000      2378.000000    34.170000
# 50%          34.000000    86.330000      5545.000000    53.930000
# 75%          43.000000   114.840000      7689.000000    68.990000
# max          59.000000   214.300000      9997.000000   103.420000
#
#               MSRP    creditLimit
# count  2649.000000    2649.000000
# mean    101.121669  108183.352208
# std      40.141181   49516.266346
# min      33.190000   11000.000000
# 25%      68.790000   77900.000000
# 50%      99.210000   95100.000000
# 75%     124.440000  119600.000000
# max     214.300000  227600.000000

# %%
df.describe(include='all')
# Out:
#         quantityOrdered    priceEach   orderDate requiredDate shippedDate  \
# count       2649.000000  2649.000000        2649         2634        2587
# unique              NaN          NaN         229          229         216
# top                 NaN          NaN  2018-11-14   2019-10-24  2019-11-07
# freq                NaN          NaN          38           39          47
# mean          34.748207    91.008335         NaN          NaN         NaN
# std            9.014277    36.682176         NaN          NaN         NaN
# min           20.000000    26.550000         NaN          NaN         NaN
# 25%           27.000000    62.050000         NaN          NaN         NaN
# 50%           34.000000    86.330000         NaN          NaN         NaN
# 75%           43.000000   114.840000         NaN          NaN         NaN
# max           59.000000   214.300000         NaN          NaN         NaN
#
#        orderStatus                                      orderComments  \
# count         2649                                                638
# unique           4                                                 31
# top        Shipped  Customer requested that DHL is used for this s...
# freq          2535                                                 48
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#                         productName      category productScale  ...  \
# count                          2649          2649         2649  ...
# unique                          109             7            8  ...
# top     1992 Ferrari 360 Spider red  Classic Cars         1:18  ...
# freq                             47           905         1013  ...
# mean                            NaN           NaN          NaN  ...
# std                             NaN           NaN          NaN  ...
# min                             NaN           NaN          NaN  ...
# 25%                             NaN           NaN          NaN  ...
# 50%                             NaN           NaN          NaN  ...
# 75%                             NaN           NaN          NaN  ...
# max                             NaN           NaN          NaN  ...
#
#                          employeeEmail   jobTitle  city_office  \
# count                             2649       2649         2649
# unique                              15          1            7
# top     ghernande@classicmodelcars.com  Sales Rep        Paris
# freq                               312       2649          811
# mean                               NaN        NaN          NaN
# std                                NaN        NaN          NaN
# min                                NaN        NaN          NaN
# 25%                                NaN        NaN          NaN
# 50%                                NaN        NaN          NaN
# 75%                                NaN        NaN          NaN
# max                                NaN        NaN          NaN
#
#              phone_office country_office territory      employeeName  \
# count                2649           2649      1680              2649
# unique                  7              5         3                15
# top     +33 1 47 23 44 04            USA      EMEA  Gerard Hernandez
# freq                  811            969      1250               312
# mean                  NaN            NaN       NaN               NaN
# std                   NaN            NaN       NaN               NaN
# min                   NaN            NaN       NaN               NaN
# 25%                   NaN            NaN       NaN               NaN
# 50%                   NaN            NaN       NaN               NaN
# 75%                   NaN            NaN       NaN               NaN
# max                   NaN            NaN       NaN               NaN
#
#           contactName                  address_office  \
# count            2649                            2649
# unique             98                               7
# top     Diego  Freyre  43 Rue Jouffroy Dabbans  75017
# freq              198                             811
# mean              NaN                             NaN
# std               NaN                             NaN
# min               NaN                             NaN
# 25%               NaN                             NaN
# 50%               NaN                             NaN
# 75%               NaN                             NaN
# max               NaN                             NaN
#
#                  address_customer
# count                        2649
# unique                         98
# top     C/ Moralzarzal, 86  28034
# freq                          198
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
#
# [11 rows x 29 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                  quantityOrdered  priceEach  quantityInStock  buyPrice  \
# quantityOrdered         1.000000   0.025279         0.018629  0.024206
# priceEach               0.025279   1.000000         0.053668  0.904234
# quantityInStock         0.018629   0.053668         1.000000  0.055187
# buyPrice                0.024206   0.904234         0.055187  1.000000
# MSRP                    0.021140   0.983178         0.052951  0.918768
# creditLimit             0.023795   0.001947        -0.020200  0.008320
#
#                      MSRP  creditLimit
# quantityOrdered  0.021140     0.023795
# priceEach        0.983178     0.001947
# quantityInStock  0.052951    -0.020200
# buyPrice         0.918768     0.008320
# MSRP             1.000000     0.002009
# creditLimit      0.002009     1.000000

# %%
plt.rcParams['figure.figsize'] = (12,8)
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='RdBu', vmin=-1, vmax=1, center=0)
plt.show()
